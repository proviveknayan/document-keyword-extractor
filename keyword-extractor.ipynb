# %%
import PyPDF2
import textract
import pandas as pd
from rake_nltk import Rake

# %%
filename ='as_a_man_thinketh.pdf' 

pdfObject = open(filename,'rb')
pdfReadable = PyPDF2.PdfReader(pdfObject)
numberOfPages = len(pdfReadable.pages)

count = 0
text = ""
                                                            
while count < numberOfPages:
    pageObject = pdfReadable.pages[count]
    count +=1
    text += pageObject.extract_text()

# because PyPDF2 cannot read scanned files, check if it returned words    
if text != "":
    text = text

# if not, run the textract to convert scanned/image based PDF files into text
else:
    text = textract.process(filename,method='tesseract',language='eng')

# %%
# execute the following two lines of code if using stopwords from the NLTK package for the first time
# import nltk 
# nltk.download('stopwords')

# to use the stopwords, load them from the package by executing the following line of code
# from nltk.corpus import stopwords

r = Rake()
r.extract_keywords_from_text(text)

# %%
phrases = r.get_ranked_phrases_with_scores()

# %%
table = pd.DataFrame(phrases,columns=['score','Phrase'])
table = table.sort_values('score',ascending=False)
table.head(50)
# Out:
#         score                                          Phrase
# 0   27.366667      would attain highly must sacrifice greatly
# 1   22.985714   would accomplish little must sacrifice little
# 2   19.966667          would achieve much must sacrifice much
# 3   19.133333          equipoise would mean total destruction
# 4   17.523810  bestial indulgence could neither think clearly
# 5   17.350000                mere external facts cannot serve
# 6   15.766667               whatsoever conditions ye may live
# 7   15.325758             honest man almost entirely virtuous
# 8   15.049607                   good thoughts bear good fruit
# 9   14.800000                  laboring humanity would perish
# 10  13.666667                       washed every sinful stain
# 11  13.000000                   larger scope takes possession
# 12  12.233333              though nearly always unconsciously
# 13  12.109091                  dishonest man likewise garners
# 14  12.066667                           middle age whose face
# 15  12.051948                        minded man fall suddenly
# 16  11.675758                     weak man must become strong
# 17  11.575758                      honest man obnoxious vices
# 18  11.566667                            hard fate shall bind
# 19  10.727969                          bad thoughts bad fruit
# 20  10.601449                               mind hath made us
# 21  10.533333                       last grow divinely strong
# 22  10.509091                      man cannot directly choose
# 23  10.026316                 physician like cheerful thought
# 24  10.000000                     peace toward every creature
# 25   9.800000                               would steer clear
# 26   9.670455                  make great personal sacrifices
# 27   9.666667           observing another become intellectual
# 28   9.625000                      longer desires impure food
# 29   9.500000                      varied almost indefinitely
# 30   9.466667                      surely though less rapidly
# 31   9.444444                       never produce bad results
# 32   9.357143                  fear never accomplish anything
# 33   9.273863                         mind hath evil thoughts
# 34   9.267424                           man whose sole object
# 35   9.168740                         man whose first thought
# 36   9.166667                             acquire wealth must
# 37   9.125000                  purpose becomes creative force
# 38   9.105263                      never produce good results
# 39   9.075758                          nature helps every man
# 40   9.000000                                 wherever ye may
# 41   9.000000                           stanton kirkham davis
# 42   9.000000                             mere external force
# 43   9.000000                          luminous center around
# 44   9.000000                            james allen foreword
# 45   9.000000                   innumerable destinies revolve
# 46   9.000000                   exquisitely adjusted pictures
# 47   9.000000                       conclusion usually formed
# 48   9.000000                         burden unjustly imposed
# 50   8.833333                               bring forth fruit
