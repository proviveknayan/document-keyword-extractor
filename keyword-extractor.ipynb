# %%
import PyPDF2
import textract
import pandas as pd
from rake_nltk import Rake

# %%
filename ='gfod-doc.pdf' 

pdfObject = open(filename,'rb')
pdfReadable = PyPDF2.PdfReader(pdfObject)
numberOfPages = len(pdfReadable.pages)

count = 0
text = ""
                                                            
while count < numberOfPages:
    pageObject = pdfReadable.pages[count]
    count +=1
    text += pageObject.extract_text()
    
if text != "":
    text = text

else:
    text = textract.process(filename,method='tesseract',language='eng')

# %%
r = Rake()
r.extract_keywords_from_text(text)

# %%
phrases = r.get_ranked_phrases_with_scores()

# %%
table = pd.DataFrame(phrases,columns=['score','Phrase'])
table = table.sort_values('score',ascending=False)
table.head(50)
# Out:
#           score                                             Phrase
# 0   3578.971711  modern slavery 137 nhrc 2019 138 nhrc 2019 139...
# 1   2804.023050  desh tier 2 tier 2 tier 2 tier 2 2019 tier 2 w...
# 2    358.219680  2019 unodc 2021 nhrc 2019 freedom fund 2018 ti...
# 3    356.072222  author contents iforeword .......................
# 4    302.580503  158 143 spl programme 2021 144 unaids 2017 145...
# 5    240.759828  caste census sops standard operating procedure...
# 6    231.942198  2020 165 spl programme 2021 166 unaids 2017 16...
# 7    167.764834  2021 112 nchr pakistan 113 piler 2010 114 hwa ...
# 8    156.125960  2016 tribhuvan university 2020 spl programme 2...
# 9    122.969771  ‘ forced religious conversions ’ ................
# 10   122.482966  absolute numbers 3rd 4th 5th 6th 7th 8th 9th 1...
# 11   121.531469  8th 1st 32 nd 10 th 74 th 12 th 64 th 30 th co...
# 12   118.328614  acquired immunodeficiency syndrome hrc human r...
# 13   109.854532  204 bangladesh 2013 hazardous work list 205 si...
# 14   106.775935         consistent tier 2 denotes positive efforts
# 15   103.497435                                  watch tier 2 list
# 16   101.727718                          tier 2 watchlist 23 forms
# 17   101.591038  dalit studies ilo international labour organis...
# 18    96.367286  38 iids sri lanka 2009 39 iids sri lanka 2009 ...
# 19    95.253637  study pakistan north korea nigeria iran indone...
# 20    94.375945  2021 nchr pakistan piler 2010 hwa 2019 tip 202...
# 21    93.093834  mohua 2017 kara 2014 al jazeera 2019 piler 201...
# 22    92.192984  like practices ..................................
# 23    91.966021  like practices :.................................
# 24    91.815617                                             tier 2
# 25    91.815617                                             tier 2
# 26    91.105739  kara 2014 109 al jazeera 2019 110 piler 2010 1...
# 27    86.102887                                 2021 wl represents
# 28    85.806309  xi glossary adrf asia dalit rights forum aes a...
# 29    82.456226  international human rights mechanisms ...........
# 30    82.366787  addressed urgently ..............................
# 31    81.684264  2007 33 iids sri lanka 2009 34 iids sri lanka ...
# 32    81.009873  foreword coen kompier senior specialist intern...
# 33    80.944340  sri lanka yes yes yes yes yes yes yes yes yes yes
# 34    80.579193  modern slavery ..................................
# 35    77.339286                                           tier 2wl
# 36    73.205977  aids undp united nations development programme...
# 37    72.972624  8th 53 rd 55 th 92 nd 130 th estimated prevalence
# 38    72.366062  2007 iids sri lanka 2009 references iexecutive...
# 39    67.921112  indian express 2021 clj 2019 tip 2021 52 commu...
# 40    67.882243  2018 214 tip 2021 35 national response mechani...
# 41    65.004715               mole hwa 2019 tip 2021 nagorik udyog
# 42    64.133245  vr 2019 36 iids sri lanka 2009 37 jiggins 1979...
# 43    64.040896  like practices ..................................
# 44    63.955701  sunday morning 2021 212 spl programme 2021 leg...
# 45    63.147960  report ..........................................
# 46    63.080772  sri lanka october 2021 © asia dalit rights for...
# 47    62.053222  vr 2019 43 britannica 44 aidmam 2021 45 ilo 20...
# 48    61.960381  asian tourism ema estate medical assistants gs...
# 49    60.638371           pakistan yes yes yes yes yes yes yes yes
